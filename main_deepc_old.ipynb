# %% [markdown]
# ### Import requirement library

# %%
from math import ceil
import numpy as np 
import cvxpy as cp 
import random
import matplotlib.pyplot as plt
from deepc import DeePC
from numpy import linalg
import pandas as pd

# %% [markdown]
# ### Collect Data

# %%
# Define system
A = np.array([[1.01,0.01,0],[0.01,1.01,0.01],[0,0.01,1.01]])
B = np.eye(3)
C = np.eye(3)
(n,m) = B.shape                                 # n = number of states, m = number of inputs
p = n                                           # p = number of output
        
# Simulation    
x0 = np.array([[0],[0],[1]])
t_step = 0.1
t_sim = 20.0                                    # simulation time 
n_sim = ceil(t_sim/t_step)                     # Number of simulation step n_sim >= (m+1)*(T_ini + N + n(B)) - 1
x = x0 
xData = np.empty((n,n_sim+1))
yData = np.empty((n,n_sim+1))
xData[:,[0]] = x0
yData[:,[0]] = x0
uData = np.empty((m,n_sim))

# Generate random input sequence
np.random.seed(1)
u_seq = np.array(np.random.rand(m,n_sim))
# measurement noise
mu = 0 #0.5
sigma = 0.2 # 0.2

# Collect data
for t in range(n_sim):
    u = u_seq[:, t].reshape(m, 1)
    w = np.random.normal(mu, sigma, size=(n, 1))
    x = A@x+B@u
    y = C@x+w
    uData[:,[t]] = u 
    xData[:,[t+1]] = x
    yData[:,[t+1]] = y

# %% [markdown]
# ### Create DeePC controller

# %%
# set parameters
params = {}
params['uData'] = uData
params['yData'] = yData[:,1:] #xData[:,1:]
params['N'] = 5
params['Q'] = np.eye(3)
params['R'] = np.eye(3)*10
params['lambda_slack'] = 0# 10**7
params['lambda_g'] = 1#300# 100

# create controller    
controller = DeePC(params)
# controller.create_Hankel_check()

# offline computation
controller.create_Hankel_check()      
controller.create_Hankel()
# Out:
# 33
# (33, 190)
# We are good to go!!
# (48, 193)
# 48

# %% [markdown]
# ### Generate Initial State

# %%
# Simulation    
x0 = np.array([[-20],[5],[1]])
t_step = 0.1
t_sim = 1.0;                                   # simulation time
n_sim = ceil(t_sim/t_step)                     # Number of simulation step
x = x0; 
xData_ini = np.empty((n,n_sim+1))
xData_ini[:,[0]] = x0; 
uData_ini = np.empty((m,n_sim))
yData_ini = np.empty((n,n_sim+1))
yData_ini[:,[0]] = x0; 
    
# Generate random input sequence
np.random.seed(5)
u_seq = np.array(np.random.rand(m,n_sim))

# Collect data
for t in range(n_sim):
    u = u_seq[:, t].reshape(m, 1)
    w = np.random.normal(mu, sigma, size=(n, 1))
    x = A@x+B@u
    y = C@x+w
    uData_ini[:,[t]] = u 
    xData_ini[:,[t+1]] = x
    yData_ini[:,[t+1]] = y

# %% [markdown]
# ### Simulation

# %%
# Simulation    
x0 = xData_ini[:,-1]
u_ini = np.reshape(uData_ini[:,-n:],(-1, 1), order='F') 
y_ini = np.reshape(yData_ini[:,-n:],(-1, 1), order='F') 
t_step = 0.1
t_sim = 10.0;                                  # simulation time
n_sim = ceil(t_sim/t_step)                     # Number of simulation step
x = x0.reshape(m, 1)
xLog = np.zeros((n,n_sim+1))
xLog[:,0] = x0
uLog = np.empty((m,n_sim))
costLog = np.empty((1,n_sim))
yLog = np.zeros((n,n_sim+1))
yLog[:,0] = x0
    
# run simulation
for t in range(n_sim):
    u = controller.computeInput(u_ini,y_ini).reshape(m, 1)
    # u = np.zeros((m,1))
    x = A@x+B@u    
    w = np.random.normal(mu, sigma, size=(n, 1))
    y = C@x+w
    u_vec = np.reshape(u,(-1, 1))
    x_vec = np.reshape(x,(-1, 1))
    y_vec = np.reshape(y,(-1, 1))
    cost = x_vec.T @ params['Q'] @ x_vec + u_vec.T @ params['R'] @ u_vec
    uLog[:,[t]] = u_vec
    xLog[:,[t+1]] = x_vec
    yLog[:,[t+1]] = y_vec
    costLog[0,[t]] = cost
    u_ini = np.block([[u_ini[n:]],[u_vec]])
    y_ini = np.block([[y_ini[n:]],[y_vec]])

# %% [markdown]
# #### Plot Result

# %%
# Plot system evolution    
y_plot = plt.figure(1)
time = np.linspace(0,t_sim,n_sim+1)

plt.subplot(311)
plt.plot(time,xLog[0,:])
plt.ylabel('y1')
plt.title('State')

plt.subplot(312)
plt.plot(time,xLog[1,:])   
plt.ylabel('y2')

plt.subplot(313)
plt.plot(time,xLog[2,:])
plt.ylabel('y3')


# Plot input evolution    
u_plot = plt.figure(2)
time = np.linspace(0,t_sim,n_sim);
plt.subplot(311)
plt.step(time,uLog[0,:])
plt.ylabel('u1')
plt.title('Input')

plt.subplot(312)
plt.step(time,uLog[1,:])   
plt.ylabel('u2')

plt.subplot(313)
plt.step(time,uLog[2,:])
plt.ylabel('u3')

plt.show()

# %% [markdown]
# #### Check

# %%
# Simulation    
x0 = xData_ini[:,-1]
u_ini = np.reshape(uData_ini[:,-n:],(-1, 1), order='F') 
y_ini = np.reshape(xData_ini[:,-n:],(-1, 1), order='F') 
t_step = 0.1
t_sim = 0.5                                    # simulation time
n_sim = ceil(t_sim/t_step)                     # Number of simulation step
x = x0.reshape(m, 1)
xLog = np.zeros((n,n_sim+1))
xLog[:,0] = x0
uLog = np.empty((m,n_sim))
costLog = np.empty((1,n_sim))

(gg, uPred, yPred) = controller.computeDeePC(u_ini,y_ini)
   
# run simulation
for t in range(n_sim):
    u = controller.computeInput(u_ini,y_ini).reshape(m, 1)
    x = A@x+B@u    
    w = np.random.normal(mu, sigma, size=(n, 1))
    x = x + w
    u_vec = np.reshape(u,(-1, 1))
    x_vec = np.reshape(x,(-1, 1))
    cost = x_vec.T @ params['Q'] @ x_vec + u_vec.T @ params['R'] @ u_vec
    uLog[:,[t]] = u_vec
    xLog[:,[t+1]] = x_vec
    costLog[0,[t]] = cost
    y = x_vec
    u_ini = np.block([[u_ini[n:]],[u_vec]])
    y_ini = np.block([[y_ini[n:]],[y]])
# Out:
# [[-4.95817086e-06]
#  [ 1.83290625e-04]
#  [ 1.19936995e-01]
#  [-1.18486637e-05]
#  [ 5.24420626e+00]
#  [ 1.22351814e-01]
#  [ 5.76216052e+00]
#  [ 6.05669483e-01]
#  [ 2.16780619e+00]
#  [ 1.97812735e+00]
#  [ 2.73682499e+00]
#  [ 1.03604828e-05]
#  [ 1.69718762e-05]
#  [ 5.34515951e-05]
#  [-3.67363101e-05]
#  [-1.63857722e-05]
#  [-7.71764245e-01]
#  [-5.70869409e-05]
#  [ 5.78743213e-05]
#  [-5.22112155e-05]
#  [-1.71439882e+00]
#  [-3.85670543e+00]
#  [-7.51676203e+00]
#  [ 5.78392388e-05]
#  [-1.07699678e+00]
#  [-1.82783219e-01]
#  [-3.62516785e-05]
#  [-8.93662015e-02]
#  [-1.26435078e-04]
#  [-6.83326959e-04]
#  [-4.75430194e-05]
#  [ 3.25122043e-01]
#  [ 3.98061358e+00]
#  [ 5.63213691e-05]
#  [ 6.26324584e-05]
#  [ 1.04005488e+00]]
# [[-4.95817086e-06]
#  [ 1.83290625e-04]
#  [ 1.19936995e-01]
#  [-1.18486637e-05]
#  [ 5.24420626e+00]
#  [ 1.22351814e-01]
#  [ 5.76216052e+00]
#  [ 6.05669483e-01]
#  [ 2.16780619e+00]
#  [ 1.97812735e+00]
#  [ 2.73682499e+00]
#  [ 1.03604828e-05]
#  [ 1.69718762e-05]
#  [ 5.34515951e-05]
#  [-3.67363101e-05]
#  [-1.63857722e-05]
#  [-7.71764245e-01]
#  [-5.70869409e-05]
#  [ 5.78743213e-05]
#  [-5.22112155e-05]
#  [-1.71439882e+00]
#  [-3.85670543e+00]
#  [-7.51676203e+00]
#  [ 5.78392388e-05]
#  [-1.07699678e+00]
#  [-1.82783219e-01]
#  [-3.62516785e-05]
#  [-8.93662015e-02]
#  [-1.26435078e-04]
#  [-6.83326959e-04]
#  [-4.75430194e-05]
#  [ 3.25122043e-01]
#  [ 3.98061358e+00]
#  [ 5.63213691e-05]
#  [ 6.26324584e-05]
#  [ 1.04005488e+00]]
# [[ 9.08556802e-05]
#  [ 2.70344650e-05]
#  [-6.33034237e-06]
#  [ 3.10878993e-01]
#  [ 6.30323683e+00]
#  [ 2.93187375e+00]
#  [ 3.04314568e-01]
#  [ 1.95210958e+00]
#  [ 1.09741528e+00]
#  [ 5.46507452e-01]
#  [ 2.18232848e+00]
#  [ 6.52605564e-01]
#  [-5.47029021e-02]
#  [ 5.58464912e-05]
#  [-3.77958834e-02]
#  [ 7.05190081e-05]
#  [-4.59027133e-05]
#  [ 1.47495395e-05]
#  [-8.10335369e-06]
#  [ 1.63850371e+00]
#  [-2.19838742e-05]
#  [-1.35580096e+00]
#  [-6.99728378e+00]
#  [-3.00302621e+00]
#  [ 8.72902746e-05]
#  [-2.08092031e+00]
#  [-5.85212220e-05]
#  [ 5.87640792e-02]
#  [-6.74767642e-05]
#  [-1.96299284e-05]
#  [-3.50800925e-05]
#  [-7.81545961e-05]
#  [ 1.60010846e+00]
#  [ 1.89081150e+00]
#  [ 1.11996353e+00]
#  [-1.54372164e-04]]
# [[ 6.09080128e-05]
#  [ 3.10793787e-05]
#  [-3.11979034e-01]
#  [-5.43589115e-07]
#  [ 1.89782720e+00]
#  [ 2.13057346e+00]
#  [ 2.48269960e+00]
#  [ 1.55939782e+00]
#  [ 3.17510914e+00]
#  [ 2.79863482e+00]
#  [-1.33390121e-05]
#  [ 1.69381826e+00]
#  [-9.24929983e-02]
#  [-4.17003558e-05]
#  [ 6.54058725e-05]
#  [-3.07075749e-05]
#  [-5.71823805e-01]
#  [-5.74492085e-05]
#  [-2.96785233e-05]
#  [ 4.61283432e-05]
#  [-5.01686959e-05]
#  [-2.98829691e+00]
#  [-3.40646293e+00]
#  [-4.28061991e+00]
#  [-1.53550355e+00]
#  [-1.17150132e-04]
#  [-2.14388003e+00]
#  [ 1.22057202e+00]
#  [ 5.03299400e-01]
#  [ 1.69209081e+00]
#  [ 1.22227859e+00]
#  [ 2.38863943e+00]
#  [ 1.12204619e-01]
#  [ 1.38201642e-01]
#  [ 1.50526435e+00]
#  [-1.50378656e+00]]
# [[ 1.27039157e-04]
#  [-1.17311495e-06]
#  [ 5.39890546e-05]
#  [-9.07359960e-06]
#  [ 7.13162915e-01]
#  [ 2.55229467e+00]
#  [ 1.28654967e+00]
#  [ 2.12458154e+00]
#  [ 1.54603960e+00]
#  [ 3.02589087e+00]
#  [ 2.98481807e+00]
#  [-4.66792846e-05]
#  [ 9.14947136e-01]
#  [-7.49927581e-05]
#  [ 1.19267935e-04]
#  [-5.23449431e-05]
#  [-2.08821431e+00]
#  [-2.06565572e-05]
#  [ 6.05877898e-06]
#  [-6.55274044e-05]
#  [-9.94606309e-07]
#  [-8.39933650e-05]
#  [-1.59444846e+00]
#  [-2.29213771e+00]
#  [-4.62712462e+00]
#  [-1.78215268e+00]
#  [-1.82695874e-01]
#  [-4.24584918e-01]
#  [ 2.45177741e+00]
#  [ 4.85220561e-05]
#  [ 1.16034705e-05]
#  [ 8.29326033e-01]
#  [ 2.52837948e+00]
#  [ 7.09749956e-05]
#  [ 4.70534218e-05]
#  [-1.50290492e-01]]
# [[-9.36650791e-01]
#  [-1.00593820e-04]
#  [-3.82711333e-05]
#  [-3.63894471e-06]
#  [-8.47574714e-05]
#  [-5.25959694e-06]
#  [ 2.06330123e-01]
#  [ 3.53730992e+00]
#  [ 4.22039987e+00]
#  [ 2.83729625e+00]
#  [ 2.08735278e+00]
#  [ 2.48507551e+00]
#  [-1.72287658e-01]
#  [-8.22296571e-05]
#  [-2.48477209e+00]
#  [-7.79463458e-01]
#  [ 9.02577746e-01]
#  [-6.91108844e-06]
#  [-7.13179764e-05]
#  [ 7.68170620e-05]
#  [ 3.27881114e-01]
#  [-7.73337364e-05]
#  [-7.54190681e-01]
#  [-4.02166726e-01]
#  [-1.88609298e+00]
#  [-4.18541862e+00]
#  [-6.79229999e-01]
#  [ 2.39702128e-01]
#  [ 5.28405414e-05]
#  [ 4.00535545e-01]
#  [ 4.07380484e-06]
#  [ 1.43225342e+00]
#  [ 1.47523613e-05]
#  [ 1.08032254e-04]
#  [ 9.28975792e-01]
#  [ 6.39061317e-02]]

# %%
x = x0.reshape(m, 1)
xLogggg = np.zeros((3,params['N']))
for i in range(params['N']):
    u = uPred[n*i:n*i+n]
    x = A@x+B@u
    xLogggg[:,[i]] = x
    print(x)
print(xLogggg)
# Out:
# [[-15.71954944]
#  [  5.17695355]
#  [ 10.83256137]]
# [[-11.54633885]
#  [  6.71315409]
#  [ 13.43313238]]
# [[-0.18976949]
#  [ 7.04782545]
#  [12.55374407]]
# [[ 5.52288659]
#  [ 8.91835094]
#  [20.2441634 ]]
# [[12.97055457]
#  [18.20935882]
#  [24.73012598]]
# [[-15.71954944 -11.54633885  -0.18976949   5.52288659  12.97055457]
#  [  5.17695355   6.71315409   7.04782545   8.91835094  18.20935882]
#  [ 10.83256137  13.43313238  12.55374407  20.2441634   24.73012598]]

# %%
print(uPred.reshape(3,-1, order='F'))
print(yPred.reshape(3,-1, order='F'))
# Out:
# [[-0.50338453  4.27863654 11.40490121  5.64407553  7.3032556 ]
#  [-3.73800913  1.53330089  0.24867188  1.67640749  8.94415387]
#  [ 4.33675413  2.44047587 -1.08085117  7.49440363  4.19433744]]
# [[-15.9988941  -13.07348961  -0.31262303   5.35411903  11.32058717]
#  [  7.6333002    6.17324855   8.14414871   6.41003787  18.63732617]
#  [  8.37721289  11.849823     7.45684853  21.34213023  19.5328847 ]]

# %%
print(xLogggg - yPred.reshape(3,-1, order='F'))
# Out:
# [[ 0.27934467  1.52715075  0.12285354  0.16876756  1.6499674 ]
#  [-2.45634665  0.53990555 -1.09632326  2.50831308 -0.42796735]
#  [ 2.45534848  1.58330939  5.09689554 -1.09796683  5.19724128]]

# %% [markdown]
# #### Plot cost

# %%
# Plot cost evolution    
cost_plot = plt.figure(3)
time = np.linspace(0,t_sim,n_sim)
plt.plot(time,costLog[0,:])
plt.ylabel('cost')
plt.xlabel('time')
plt.title('cost')

plt.show()

# %% [markdown]
# ### Regularization

# %% [markdown]
# #### Iterate for lambda y

# %%
# Simulation   
lambda_List = [0.1,1,3,5,10,10**2,10**3,10**4,10**5,10**6,10**7] 
t_step = 0.1
t_sim = 5.0                                   # simulation time
n_sim = ceil(t_sim/t_step)                     # Number of simulation step
sumcostLog = np.empty((1,len(lambda_List)))
params['lambda_g'] = 300

# run simulation
for i in range(len(lambda_List)):
    params['lambda_slack'] = lambda_List[i]
    # create controller    
    controller = DeePC(params) 
    controller.create_Hankel()     
    # init new log
    x0 = xData_ini[:,-1]
    u_ini = np.reshape(uData_ini[:,-n:],(-1, 1), order='F') 
    y_ini = np.reshape(xData_ini[:,-n:],(-1, 1), order='F') 
    x = x0.reshape(m, 1)
    xLog = np.zeros((n,n_sim+1))
    xLog[:,0] = x0
    uLog = np.empty((m,n_sim))
    costLog = np.empty((1,n_sim))

    for t in range(n_sim):
        u = controller.computeInput(u_ini,y_ini).reshape(m, 1)
        x = A@x+B@u    
        w = np.random.normal(mu, sigma, size=(n, 1))
        x = x + w
        u_vec = np.reshape(u,(-1, 1))
        x_vec = np.reshape(x,(-1, 1))
        cost = x_vec.T @ params['Q'] @ x_vec + u_vec.T @ params['R'] @ u_vec
        uLog[:,[t]] = u_vec
        xLog[:,[t+1]] = x_vec
        costLog[0,[t]] = cost        
        y = x_vec
        u_ini = np.block([[u_ini[n:]],[u_vec]])
        y_ini = np.block([[y_ini[n:]],[y]])
    print(np.sum(costLog))
    sumcostLog[0,[i]] = np.sum(costLog)

# Plot cost evolution    
cost_plot = plt.figure(4)
plt.loglog(lambda_List,sumcostLog.reshape(-1,1))
plt.ylabel('cost')
plt.xlabel('lambda')
plt.title('cost')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# SolverError                               Traceback (most recent call last)
# Cell In [10], line 26
#      23 costLog = np.empty((1,n_sim))
#      25 for t in range(n_sim):
# ---> 26     u = controller.computeInput(u_ini,y_ini).reshape(m, 1)
#      27     x = A@x+B@u
#      28     w = np.random.normal(mu, sigma, size=(n, 1))
#
# File d:\Jzt\ETH\IFA\DeepC\deepc.py:110, in DeePC.computeInput(self, u_ini, y_ini)
#     108 def computeInput(self, u_ini, y_ini):
#     109     # Plan optimal controls and states over the next T samples
# --> 110     (g, uPred, yPred) = self.computeDeePC(u_ini,y_ini)
#     112     # Apply the first control action in the predicted optimal sequence
#     113     return uPred[:self.m,0]
#
# File d:\Jzt\ETH\IFA\DeepC\deepc.py:104, in DeePC.computeDeePC(self, u_ini, y_ini)
#     102 constraints += [self.Hankel_Y_f @ g == y]
#     103 problem = cp.Problem(cp.Minimize(objective), constraints)
# --> 104 problem.solve()
#     106 return (g.value, u.value, y.value)
#
# File c:\Users\Jzeta\anaconda3\envs\ifaenv\lib\site-packages\cvxpy\problems\problem.py:481, in Problem.solve(self, *args, **kwargs)
#     479 else:
#     480     solve_func = Problem._solve
# --> 481 return solve_func(self, *args, **kwargs)
#
# File c:\Users\Jzeta\anaconda3\envs\ifaenv\lib\site-packages\cvxpy\problems\problem.py:1020, in Problem._solve(self, solver, warm_start, verbose, gp, qcp, requires_grad, enforce_dpp, ignore_dpp, **kwargs)
#    1018 end = time.time()
#    1019 self._solve_time = end - start
# -> 1020 self.unpack_results(solution, solving_chain, inverse_data)
#    1021 if verbose:
#    1022     print(_FOOTER)
#
# File c:\Users\Jzeta\anaconda3\envs\ifaenv\lib\site-packages\cvxpy\problems\problem.py:1345, in Problem.unpack_results(self, solution, chain, inverse_data)
#    1343     warnings.warn(INF_OR_UNB_MESSAGE)
#    1344 if solution.status in s.ERROR:
# -> 1345     raise error.SolverError(
#    1346             "Solver '%s' failed. " % chain.solver.name() +
#    1347             "Try another solver, or solve with verbose=True for more "
#    1348             "information.")
#    1350 self.unpack(solution)
#    1351 self._solver_stats = SolverStats(self._solution.attr,
#    1352                                  chain.solver.name())
#
# SolverError: Solver 'OSQP' failed. Try another solver, or solve with verbose=True for more information.

# %% [markdown]
# #### Iterate for lambda g

# %%
# Simulation   
lambda_List = [10**-4,10**-3,10**-2,10**-1,10**-0,10**1,10**2,10**3,10**4] 
t_step = 0.1
t_sim = 1.0                                   # simulation time
n_sim = ceil(t_sim/t_step)                     # Number of simulation step
sumcostLog = np.empty((1,len(lambda_List)))
params['lambda_slack'] = 0

# run simulation
for i in range(len(lambda_List)):
    params['lambda_g'] = lambda_List[i]
    # create controller    
    controller = DeePC(params) 
    controller.create_Hankel()     
    # init new log
    x0 = xData_ini[:,-1]
    u_ini = np.reshape(uData_ini[:,-n:],(-1, 1), order='F') 
    y_ini = np.reshape(xData_ini[:,-n:],(-1, 1), order='F') 
    x = x0.reshape(m, 1)
    xLog = np.zeros((n,n_sim+1))
    xLog[:,0] = x0
    uLog = np.empty((m,n_sim))
    costLog = np.empty((1,n_sim))

    for t in range(n_sim):
        u = controller.computeInput(u_ini,y_ini).reshape(m, 1)
        x = A@x+B@u    
        w = np.random.normal(mu, sigma, size=(n, 1))
        x = x + w
        u_vec = np.reshape(u,(-1, 1))
        x_vec = np.reshape(x,(-1, 1))
        cost = x_vec.T @ params['Q'] @ x_vec # + u_vec.T @ params['R'] @ u_vec
        print(cost)
        uLog[:,[t]] = u_vec
        xLog[:,[t+1]] = x_vec
        costLog[0,[t]] = cost        
        y = x_vec
        u_ini = np.block([[u_ini[n:]],[u_vec]])
        y_ini = np.block([[y_ini[n:]],[y]])
    print(np.sum(costLog))
    sumcostLog[0,[i]] = np.sum(costLog)

# Plot cost evolution    
cost_plot = plt.figure(4)
plt.loglog(lambda_List,sumcostLog.reshape(-1,1))
plt.ylabel('cost')
plt.xlabel('lambda')
plt.title('cost')
plt.show()
# Out:
# (48, 193)
# 48
# [[380.46077375]]
# [[384.08155145]]
# [[381.97057516]]
# [[387.31909531]]
# [[389.55654891]]
# [[385.89051157]]
# [[380.10335723]]
# [[385.77170942]]
# [[389.36766137]]
# [[391.03826244]]
# 3855.5600466132814
# (48, 193)
# 48
# [[364.5831603]]
# [[364.59970747]]
# [[356.32593201]]
# [[356.1875525]]
# [[349.92658854]]
# [[346.55665809]]
# [[348.53851393]]
# [[349.85064869]]
# [[349.15275532]]
# [[354.68463472]]
# 3540.406151558557
# (48, 193)
# 48
# [[369.03387027]]
# [[366.57486659]]
# [[353.58149969]]
# [[343.39811233]]
# [[352.99041702]]
# [[346.88234243]]
# [[343.92736356]]
# [[333.67222168]]
# [[341.22222365]]
# [[357.53930775]]
# 3508.8222249651635
# (48, 193)
# 48
# [[356.80610078]]
# [[350.98150487]]
# [[335.14899206]]
# [[324.80366396]]
# [[313.50915828]]
# [[306.92097911]]
# [[294.18692754]]
# [[284.77891706]]
# [[279.23733846]]
# [[280.40082945]]
# 3126.774411569694
# (48, 193)
# 48
# [[292.68368578]]
# [[222.55907478]]
# [[180.75065405]]
# [[144.71666752]]
# [[121.68129036]]
# [[100.4720187]]
# [[83.03557625]]
# [[73.44200638]]
# [[60.93928289]]
# [[49.72950705]]
# 1330.0097637577685
# (48, 193)
# 48
# [[239.72154808]]
# [[148.05342384]]
# [[100.20966138]]
# [[69.55576596]]
# [[43.66104166]]
# [[29.22325064]]
# [[20.90557728]]
# [[15.31362496]]
# [[11.54126401]]
# [[8.56098961]]
# 686.7461474209914
# (48, 193)
# 48
# [[279.19523802]]
# [[219.16273352]]
# [[171.08494466]]
# [[138.86439407]]
# [[113.9578305]]
# [[86.67525066]]
# [[68.14336044]]
# [[51.27525025]]
# [[44.83907808]]
# [[34.20200347]]
# 1207.4000836626424
# (48, 193)
# 48
# [[310.80027775]]
# [[258.41910645]]
# [[239.37482661]]
# [[232.88516925]]
# [[252.40795796]]
# [[287.56144723]]
# [[337.19990552]]
# [[382.43854484]]
# [[425.34505764]]
# c:\Users\Jzeta\anaconda3\envs\ifaenv\lib\site-packages\cvxpy\problems\problem.py:1337: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# [[445.58202793]]
# 3172.0143211946406
# (48, 193)
# 48
# [[325.47786708]]
# [[295.22619049]]
# [[289.83798033]]
# [[294.40753173]]
# [[323.40959931]]
# [[371.89786888]]
# [[462.00904429]]
# [[574.43050976]]
# [[702.68241071]]
# [[872.51718993]]
# 4511.896192517437

# %%
print(sumcostLog)
# Out:
# [[11082.88848805 12354.94068198 39213.04805546 23622.23959274
#    2403.61590164  4398.73157901 10000.44750838 49549.58108353
#    9460.97218814]]
